# %% [markdown]
# # Echo top height calculation from NEXRAD PPI volume data:

# %% [markdown]
# An echo top is the radar indicated top of an area of precipitation. This notebook demonstrates how to calculate the echo top height (ETH) in a NEXRAD PPI volume scan to determine the maximum elevation angle at which a certain reflectivity threshold is exceeded.
#
# This example uses the echo top height (ETH) calculation code written by [Valentin Louf](https://github.com/vlouf), available at this [github repository](https://github.com/vlouf/eth_radar.git).

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
#
# The notebook applies the modified ETH algorithm proposed by [Lakshmanan et al. (2013)](https://journals.ametsoc.org/view/journals/wefo/28/2/waf-d-12-00084_1.xml) to a NEXRAD PPI volume scan.
#
# The modified algorithm comprises these steps:
#
# 1. Find the maximum elevation angle ($\theta_{b}$) where reflectivity ($Z_{b}$) exceeds the echo-top reflectivity threshold.
# If $\theta_{b}$ is not the highest elevation scan in the virtual volume, obtain the reflectivity value ($Z_{a}$) at the next higher elevation angle ($\theta_{a}$). Then, the echo-top height is given by the height of the radar beam at an elevation angle:
#
# $$\theta_T = (Z_T - Z_a) \frac{\theta_b - \theta_a}{Z_b - Z_a} + \theta_b$$
#
# where $Z_T$ is the threshold value (e.g., 0 dBZ, 18 dBZ) used to compute the echo top.
#
# 2. If $\theta_{b}$ is the highest elevation scan available, set $\theta_{T} = \theta_{b} + \beta/2$, where $\beta$ is the half-power beamwidth. This condition is met far away from the radar if higher-elevation scans have shorter ranges than a base “surveillance” scan and very close to the radar if the highest-elevation scan does not sample the top of the cloud. Under these circumstances, $\theta_{T}$ is set to be the top of the beam containing dBZ $\geq Z_T$; that is, the traditional echo-top algorithm is followed when there are no data available from a higher-elevation scan.

# %% [markdown]
# ## Prerequisites
#
# | Concepts | Importance | Notes |
# | --- | --- | --- |
# | [Matplotlib Basics](https://foundations.projectpythia.org/core/matplotlib/matplotlib-basics.html) | Required | Basic plotting |
# | [Intro to Cartopy](https://foundations.projectpythia.org/core/cartopy/cartopy.html) | Required | Geospatial plotting |
# | [Py-ART Basics](../foundations/pyart-basics) | Required | IO/Visualization |
# | [Numba](https://numba.pydata.org/) | Helpful | Familiarity with vectorization/optimization of Python functions|
#
# - **Time to learn**: 25 minutes

# %% [markdown]
# ## Imports

# %%
import os
import pyart
import numpy as np
from echotop import cloud_top_height, grid_cloud_top
import matplotlib.pyplot as plt
import cartopy.crs as ccrs

# %%
FILLVALUE: int = -9999 
RANGE_STEP: int = 1000 
MAX_RANGE: float = 250e3 
# Define the root directory where UF radar data files are located
root_directory = './UF'

# Define the output directory for PNG files
output_directory = './radar_png'

# %% [markdown]
# ## Define our function to compute ETH on a uniform x-y grid
#
# The input file can be a Next Generation Weather Radar (NEXRAD) archive file from Amazon Web Services. We will remotely access  this file and use a reflectivity threshold `eth_thld` to define our echo tops.

# %%
def compute_eth(file_path, eth_thld=0):
    """
    Compute the Echo Top Height on a grid
    
    Parameters
    ==========
    infile (str): Filename of NEXRAD Level 2 Archive file. The files hosted by
    at the NOAA National Climate Data Center [1]_ as well as on the
    UCAR THREDDS Data Server [2]_ have been tested. Other NEXRAD
    Level 2 Archive files may or may not work. Message type 1 file
    and message type 31 files are supported.
    
    eth_thld (float): Reflectivity threshold for which we want to compute 
    the echo top height.
        
    Returns:
    ========
    cth_grid: ndarray <x, y>
        Echo top height on a grid of dimension (x, y).  
        
    References
    ----------
    .. [1] http://www.ncdc.noaa.gov/
    .. [2] http://thredds.ucar.edu/thredds/catalog.html
    """
    # Reading NEXRAD L2 data stored on AWS cloud
    
    radar = pyart.io.read(file_path)

    r = radar.range['data']
    azimuth = radar.azimuth['data']
    elevation = radar.elevation['data']
    refl = np.array(radar.fields['reflectivity']['data'])
    st_sweep = radar.sweep_start_ray_index['data']
    ed_sweep = radar.sweep_end_ray_index['data']

    # Compute ETH. The 'echotop' package uses @jit decorator to optimize 
    # the 'cloud_top_height' function
    cth = cloud_top_height(r, azimuth, elevation, st_sweep, ed_sweep, refl, eth_thld=eth_thld)

    # Grid data
    th = 450 - azimuth[slice(st_sweep[0], ed_sweep[0] + 1)]
    th[th < 0] += 360

    R, A = np.meshgrid(r, th)
    x = R * np.cos(np.pi * A / 180)
    y = R * np.sin(np.pi * A / 180)

    xgrid = np.arange(-MAX_RANGE, MAX_RANGE + RANGE_STEP / 2, RANGE_STEP).astype(np.int32)
    [X, Y] = np.meshgrid(xgrid, xgrid)
    cth_grid = grid_cloud_top(
        cth, x, y, X, Y, nnearest=24, maxdist=2500
    )  # nearest=24 should be enough to sample out to 2500m on a 1000m grid
    cth_grid = np.ma.masked_invalid(cth_grid).astype(np.int32).filled(FILLVALUE)

    return cth_grid

# %% [markdown]
# ## Read and plot reflectivity and velocity fields for a sample file

# %%
aws_nexrad_level2_file = (
    "s3://noaa-nexrad-level2/2022/03/22/KHGX/KHGX20220322_120125_V06"
)

file_path="./UF/NHB190510234240.uf"

radar = pyart.io.read(file_path)


fig = plt.figure(figsize=(12, 4))
display = pyart.graph.RadarMapDisplay(radar)

ax = plt.subplot(121, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    "reflectivity",
    sweep=0,
    ax=ax,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    vmin=-20,
    vmax=60,
)

ax = plt.subplot(122, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    "velocity",
    sweep=1,
    ax=ax,
    colorbar_label="Radial Velocity ($V_{r}$) \n (m/s)",
    vmin=-70,
    vmax=70,
)

# %% [markdown]
# ## Define some global constants and compute the ETH on a horizontally uniform grid
#
# These constants are required by the `compute_eth` function to grid the data from polar coordinates to a horizontally uniform grid. These three constants are defined as:
#
# `FILLVALUE` (Value to replace missing data)\
# `RANGE_STEP` (Uniform horizontal grid spacing in x and y dimensions)\
# `MAX_RANGE` (Maximum range up to which ETH to be calculated from gridded data)

# %% [markdown]
# ## Plot the gridded echo/cloud top height using matplotlib

# %%
cth_grid = compute_eth(file_path, eth_thld=20)

p = plt.pcolormesh(cth_grid,
                   vmin=0,
                   vmax=15000,
                   cmap='pyart_ChaseSpectral')

plt.colorbar(mappable=p)
# Out:
# /var/folders/ny/hxv5b40s3w93s_yc2kzgz28m0000gn/T/ipykernel_54818/1515337924.py:54: RuntimeWarning: invalid value encountered in cast
#   cth_grid = np.ma.masked_invalid(cth_grid).astype(np.int32).filled(FILLVALUE)

# %% [markdown]
# ---

# %% [markdown]
# ## Summary
# Within this example, we walked through how to access ARM data from a field campaign in Texas, plot a quick look of the RHI scan data, and grid our RHI data from native (polar) coordinates to a uniform range-height Caretsian grid.

# %% [markdown]
# ## Resources and References
# * [NOAA NEXRAD on AWS](https://registry.opendata.aws/noaa-nexrad/)
# * [Read NEXRAD on AWS](https://arm-doe.github.io/pyart/examples/io/plot_nexrad_data_aws.html#sphx-glr-examples-io-plot-nexrad-data-aws-py)
# * Py-ART:
#     - Helmus, J.J. & Collis, S.M., (2016). The Python ARM Radar Toolkit (Py-ART), a Library for Working with Weather Radar Data in the Python Programming Language. Journal of Open Research Software. 4(1), p.e25. DOI: http://doi.org/10.5334/jors.119
# * Echo-top height algorithm:
#     - Lakshmanan, V., Hondl, K., Potvin, C. K., & Preignitz, D. (2013). An improved method for estimating radar echo-top height. Weather and Forecasting, 28(2), 481-488. DOI: https://doi.org/10.1175/WAF-D-12-00084.1

# %%
def process_uf_file(file_path, output_directory=output_directory):
    try:    
        # Create the output directory if it doesn't exist
        os.makedirs(output_directory, exist_ok=True)

        # Plot reflectivity data
        cth_grid = compute_eth(file_path, eth_thld=20)

        p = plt.pcolormesh(cth_grid,
                        vmin=0,
                        vmax=15000,
                        cmap='pyart_ChaseSpectral')

        plt.colorbar(mappable=p)

        # Export the plot as an image file to the output directory
        output_filename = os.path.join(output_directory, os.path.basename(file_path).replace('.uf', '.png'))
        plt.savefig(output_filename, dpi=100)
        plt.close()

        print(f'Processed: {file_path}')
    except Exception as e:
        print(f'Error processing {file_path}: {str(e)}')

# %%
# Recursively traverse the directory and its subdirectories
for root, dirs, files in os.walk(root_directory):
    for file in files:
        if file.endswith('.uf') is False:
            continue

        file_path = os.path.join(root, file)
        process_uf_file(file_path, output_directory='./echotop_png')

print(f'PNG files exported to: {output_directory}')
# Out:
# /Users/kiettran/miniforge3/envs/pyart_env/lib/python3.11/site-packages/pyart/io/sigmet.py:146: UserWarning: Unknown type: 17, returning raw data
#   sigmet_data, sigmet_metadata = sigmetfile.read_data(full_xhdr=full_xhdr)
# /var/folders/ny/hxv5b40s3w93s_yc2kzgz28m0000gn/T/ipykernel_54818/1515337924.py:54: RuntimeWarning: invalid value encountered in cast
#   cth_grid = np.ma.masked_invalid(cth_grid).astype(np.int32).filled(FILLVALUE)
# Processed: ./UF/NHB190513055006.uf
# Processed: ./UF/NHB190511023008.uf
# Processed: ./UF/NHB190513110240.uf
# Processed: ./UF/NHB190513054008.uf
# Processed: ./UF/NHB190513110007.uf
# Processed: ./UF/NHB190511002240.uf
# Processed: ./UF/NHB190511034239.uf
# Processed: ./UF/NHB190511103008.uf
# Processed: ./UF/NHB190511102006.uf
# Processed: ./UF/NHB190513075240.uf
# Processed: ./UF/NHB190512231006.uf
# Processed: ./UF/NHB190513043239.uf
# Processed: ./UF/NHB190512030007.uf
# Processed: ./UF/NHB190513115008.uf
# Processed: ./UF/NHB190513014240.uf
# Processed: ./UF/NHB190511010239.uf
# Processed: ./UF/NHB190511055239.uf
# Processed: ./UF/NHB190511063240.uf
# Processed: ./UF/NHB190511063007.uf
# Processed: ./UF/NHB190512014007.uf
# Processed: ./UF/NHB190513051007.uf
# Processed: ./UF/NHB190513014007.uf
# Processed: ./UF/NHB190513102239.uf
# Processed: ./UF/NHB190511042008.uf
# Processed: ./UF/NHB190511130239.uf
# Processed: ./UF/NHB190511143240.uf
# Processed: ./UF/NHB190512235240.uf
# Processed: ./UF/NHB190513091240.uf
# Processed: ./UF/NHB190511143007.uf
# Processed: ./UF/NHB190511095239.uf
# Processed: ./UF/NHB190511132239.uf
# Processed: ./UF/NHB190510233239.uf
# Processed: ./UF/NHB190512145239.uf
# Processed: ./UF/NHB190513100239.uf
# Processed: ./UF/NHB190513093240.uf
# Processed: ./UF/NHB190511024240.uf
# Processed: ./UF/NHB190513053240.uf
# Processed: ./UF/NHB190513065239.uf
# Processed: ./UF/NHB190513020239.uf
# Processed: ./UF/NHB190511080008.uf
# Processed: ./UF/NHB190513004239.uf
# Processed: ./UF/NHB190512004239.uf
# Processed: ./UF/NHB190511101008.uf
# Processed: ./UF/NHB190511045240.uf
# Processed: ./UF/NHB190511000007.uf
# Processed: ./UF/NHB190512013008.uf
# Processed: ./UF/NHB190513112240.uf
# Processed: ./UF/NHB190511085007.uf
# Processed: ./UF/NHB190511021008.uf
# Processed: ./UF/NHB190511120240.uf
# Processed: ./UF/NHB190511120007.uf
# Processed: ./UF/NHB190513081239.uf
# Processed: ./UF/NHB190513073007.uf
# Processed: ./UF/NHB190511004007.uf
# Processed: ./UF/NHB190511041007.uf
# Processed: ./UF/NHB190511032239.uf
# Processed: ./UF/NHB190513045239.uf
# Processed: ./UF/NHB190512153007.uf
# Processed: ./UF/NHB190511124007.uf
# Processed: ./UF/NHB190513085239.uf
# Processed: ./UF/NHB190511060008.uf
# Processed: ./UF/NHB190511112239.uf
# Processed: ./UF/NHB190513053006.uf
# Processed: ./UF/NHB190513120239.uf
# Processed: ./UF/NHB190512153240.uf
# Processed: ./UF/NHB190511100007.uf
# Processed: ./UF/NHB190511145240.uf
# Processed: ./UF/NHB190511001008.uf
# Processed: ./UF/NHB190511020007.uf
# Processed: ./UF/NHB190511065007.uf
# Processed: ./UF/NHB190511084008.uf
# Processed: ./UF/NHB190513012007.uf
# Processed: ./UF/NHB190512012240.uf
# Processed: ./UF/NHB190513061239.uf
# Processed: ./UF/NHB190512024239.uf
# Processed: ./UF/NHB190511121008.uf
# Processed: ./UF/NHB190511053239.uf
# Processed: ./UF/NHB190512010007.uf
# Processed: ./UF/NHB190511022007.uf
# Processed: ./UF/NHB190511014239.uf
# Processed: ./UF/NHB190511123008.uf
# Processed: ./UF/NHB190512155006.uf
# Processed: ./UF/NHB190513063239.uf
# Processed: ./UF/NHB190512154008.uf
# Processed: ./UF/NHB190512010240.uf
# Processed: ./UF/NHB190513055240.uf
# Processed: ./UF/NHB190511091239.uf
# Processed: ./UF/NHB190511102240.uf
# Processed: ./UF/NHB190513075006.uf
# Processed: ./UF/NHB190510235239.uf
# Processed: ./UF/NHB190512143239.uf
# Processed: ./UF/NHB190513031008.uf
# Processed: ./UF/NHB190513074008.uf
# Processed: ./UF/NHB190513114007.uf
# Processed: ./UF/NHB190511083240.uf
# Processed: ./UF/NHB190512151240.uf
# Processed: ./UF/NHB190512015008.uf
# Processed: ./UF/NHB190513015008.uf
# Processed: ./UF/NHB190513122239.uf
# Processed: ./UF/NHB190511062008.uf
# Processed: ./UF/NHB190511110239.uf
# Processed: ./UF/NHB190511043007.uf
# Processed: ./UF/NHB190513071007.uf
# Processed: ./UF/NHB190513034007.uf
# Processed: ./UF/NHB190513071240.uf
# Processed: ./UF/NHB190512002239.uf
# Processed: ./UF/NHB190511043240.uf
# Processed: ./UF/NHB190511075239.uf
# Processed: ./UF/NHB190512234008.uf
# Processed: ./UF/NHB190511081008.uf
# Processed: ./UF/NHB190511025007.uf
# Processed: ./UF/NHB190512152006.uf
# Processed: ./UF/NHB190511025240.uf
# Processed: ./UF/NHB190511013239.uf
# Processed: ./UF/NHB190513052240.uf
# Processed: ./UF/NHB190513064239.uf
# Processed: ./UF/NHB190511105007.uf
# Processed: ./UF/NHB190511140007.uf
# Processed: ./UF/NHB190511105240.uf
# Processed: ./UF/NHB190513092007.uf
# Processed: ./UF/NHB190511140240.uf
# Processed: ./UF/NHB190513072006.uf
# Processed: ./UF/NHB190511133239.uf
# Processed: ./UF/NHB190512144239.uf
# Processed: ./UF/NHB190510232239.uf
# Processed: ./UF/NHB190513113007.uf
# Processed: ./UF/NHB190512160239.uf
# Processed: ./UF/NHB190512012008.uf
# Processed: ./UF/NHB190513113240.uf
# Processed: ./UF/NHB190511044007.uf
# Processed: ./UF/NHB190513033007.uf
# Processed: ./UF/NHB190513005239.uf
# Processed: ./UF/NHB190511145008.uf
# Processed: ./UF/NHB190512233008.uf
# Processed: ./UF/NHB190511044240.uf
# Processed: ./UF/NHB190513094006.uf
# Processed: ./UF/NHB190512031007.uf
# Processed: ./UF/NHB190513095008.uf
# Processed: ./UF/NHB190511003007.uf
# Processed: ./UF/NHB190511035239.uf
# Processed: ./UF/NHB190513111007.uf
# Processed: ./UF/NHB190513082239.uf
# Processed: ./UF/NHB190511150239.uf
# Processed: ./UF/NHB190513010008.uf
# Processed: ./UF/NHB190511142007.uf
# Processed: ./UF/NHB190511230239.uf
# Processed: ./UF/NHB190511131239.uf
# Processed: ./UF/NHB190513090007.uf
# Processed: ./UF/NHB190512234240.uf
# Processed: ./UF/NHB190513035006.uf
# Processed: ./UF/NHB190513050007.uf
# Processed: ./UF/NHB190511083008.uf
# Processed: ./UF/NHB190512151008.uf
# Processed: ./UF/NHB190512015240.uf
# Processed: ./UF/NHB190513015240.uf
# Processed: ./UF/NHB190513050240.uf
# Processed: ./UF/NHB190511054239.uf
# Processed: ./UF/NHB190511062240.uf
# Processed: ./UF/NHB190511135239.uf
# Processed: ./UF/NHB190511002008.uf
# Processed: ./UF/NHB190512230240.uf
# Processed: ./UF/NHB190511234239.uf
# Processed: ./UF/NHB190513030008.uf
# Processed: ./UF/NHB190511090239.uf
# Processed: ./UF/NHB190512230007.uf
# Processed: ./UF/NHB190511050239.uf
# Processed: ./UF/NHB190511015239.uf
# Processed: ./UF/NHB190511122008.uf
# Processed: ./UF/NHB190513062239.uf
# Processed: ./UF/NHB190512011240.uf
# Processed: ./UF/NHB190512011007.uf
# Processed: ./UF/NHB190513011007.uf
# Processed: ./UF/NHB190513035240.uf
# Processed: ./UF/NHB190513003239.uf
# Processed: ./UF/NHB190512003239.uf
# Processed: ./UF/NHB190511042240.uf
# Processed: ./UF/NHB190512235008.uf
# Processed: ./UF/NHB190513091008.uf
# Processed: ./UF/NHB190513070007.uf
# Processed: ./UF/NHB190511082007.uf
# Processed: ./UF/NHB190512150240.uf
# Processed: ./UF/NHB190512150007.uf
# Processed: ./UF/NHB190511113239.uf
# Processed: ./UF/NHB190511024008.uf
# Processed: ./UF/NHB190511061008.uf
# Processed: ./UF/NHB190513052006.uf
# Processed: ./UF/NHB190513121239.uf
# Processed: ./UF/NHB190511080240.uf
# Processed: ./UF/NHB190511125007.uf
# Processed: ./UF/NHB190513084239.uf
# Processed: ./UF/NHB190511141008.uf
# Processed: ./UF/NHB190511033239.uf
# Processed: ./UF/NHB190511104008.uf
# Processed: ./UF/NHB190511040240.uf
# Processed: ./UF/NHB190511005240.uf
# Processed: ./UF/NHB190513044239.uf
# Processed: ./UF/NHB190511040007.uf
# Processed: ./UF/NHB190511005007.uf
# Processed: ./UF/NHB190513093008.uf
# Processed: ./UF/NHB190513112008.uf
# Processed: ./UF/NHB190513025239.uf
# Processed: ./UF/NHB190513060239.uf
# Processed: ./UF/NHB190512025239.uf
# Processed: ./UF/NHB190511021240.uf
# Processed: ./UF/NHB190511052239.uf
# Processed: ./UF/NHB190511064007.uf
# Processed: ./UF/NHB190513013007.uf
# Processed: ./UF/NHB190512140239.uf
# Processed: ./UF/NHB190512032008.uf
# Processed: ./UF/NHB190513032008.uf
# Processed: ./UF/NHB190511101240.uf
# Processed: ./UF/NHB190512232240.uf
# Processed: ./UF/NHB190511045008.uf
# Processed: ./UF/NHB190511144007.uf
# Processed: ./UF/NHB190512232007.uf
# Processed: ./UF/NHB190511092239.uf
# Processed: ./UF/NHB190513022007.uf
# Processed: ./UF/NHB190512022007.uf
# Processed: ./UF/NHB190511055007.uf
# Processed: ./UF/NHB190513122006.uf
# Processed: ./UF/NHB190512014239.uf
# Processed: ./UF/NHB190513051239.uf
# Processed: ./UF/NHB190513022240.uf
# Processed: ./UF/NHB190512022240.uf
# Processed: ./UF/NHB190513102007.uf
# Processed: ./UF/NHB190511231007.uf
# Processed: ./UF/NHB190511130007.uf
# Processed: ./UF/NHB190512003008.uf
# Processed: ./UF/NHB190510231240.uf
# Processed: ./UF/NHB190511231240.uf
# Processed: ./UF/NHB190511095007.uf
# Processed: ./UF/NHB190513083240.uf
# Processed: ./UF/NHB190513062008.uf
# Processed: ./UF/NHB190512155239.uf
# Processed: ./UF/NHB190513083007.uf
# Processed: ./UF/NHB190511114240.uf
# Processed: ./UF/NHB190511050008.uf
# Processed: ./UF/NHB190511122239.uf
# Processed: ./UF/NHB190511034007.uf
# Processed: ./UF/NHB190513043007.uf
# Processed: ./UF/NHB190512030239.uf
# Processed: ./UF/NHB190513030239.uf
# Processed: ./UF/NHB190510235006.uf
# Processed: ./UF/NHB190511071240.uf
# Processed: ./UF/NHB190511135008.uf
# Processed: ./UF/NHB190513041007.uf
# Processed: ./UF/NHB190513004007.uf
# Processed: ./UF/NHB190511000239.uf
# Processed: ./UF/NHB190511073240.uf
# Processed: ./UF/NHB190512032239.uf
# Processed: ./UF/NHB190513032239.uf
# Processed: ./UF/NHB190513041240.uf
# Processed: ./UF/NHB190511085239.uf
# Processed: ./UF/NHB190513025008.uf
# Processed: ./UF/NHB190513060008.uf
# Processed: ./UF/NHB190511132007.uf
# Processed: ./UF/NHB190510233007.uf
# Processed: ./UF/NHB190512145007.uf
# Processed: ./UF/NHB190511233240.uf
# Processed: ./UF/NHB190512001008.uf
# Processed: ./UF/NHB190511141239.uf
# Processed: ./UF/NHB190511104239.uf
# Processed: ./UF/NHB190513064009.uf
# Processed: ./UF/NHB190513020007.uf
# Processed: ./UF/NHB190512020240.uf
# Processed: ./UF/NHB190513121008.uf
# Processed: ./UF/NHB190511012240.uf
# Processed: ./UF/NHB190511113008.uf
# Processed: ./UF/NHB190511061239.uf
# Processed: ./UF/NHB190511100239.uf
# Processed: ./UF/NHB190512233239.uf
# Processed: ./UF/NHB190512141240.uf
# Processed: ./UF/NHB190513104240.uf
# Processed: ./UF/NHB190511093007.uf
# Processed: ./UF/NHB190513005008.uf
# Processed: ./UF/NHB190511093240.uf
# Processed: ./UF/NHB190511020239.uf
# Processed: ./UF/NHB190511065239.uf
# Processed: ./UF/NHB190513024240.uf
# Processed: ./UF/NHB190512160008.uf
# Processed: ./UF/NHB190513012239.uf
# Processed: ./UF/NHB190513061007.uf
# Processed: ./UF/NHB190513024007.uf
# Processed: ./UF/NHB190512024007.uf
# Processed: ./UF/NHB190511053007.uf
# Processed: ./UF/NHB190512144008.uf
# Processed: ./UF/NHB190513073239.uf
# Processed: ./UF/NHB190513101008.uf
# Processed: ./UF/NHB190513000240.uf
# Processed: ./UF/NHB190512000240.uf
# Processed: ./UF/NHB190511004239.uf
# Processed: ./UF/NHB190511041239.uf
# Processed: ./UF/NHB190513045007.uf
# Processed: ./UF/NHB190513000007.uf
# Processed: ./UF/NHB190513021008.uf
# Processed: ./UF/NHB190511225239.uf
# Processed: ./UF/NHB190511012006.uf
# Processed: ./UF/NHB190511124239.uf
# Processed: ./UF/NHB190511013008.uf
# Processed: ./UF/NHB190511112007.uf
# Processed: ./UF/NHB190511081239.uf
# Processed: ./UF/NHB190511054008.uf
# Processed: ./UF/NHB190511011008.uf
# Processed: ./UF/NHB190513023008.uf
# Processed: ./UF/NHB190513114239.uf
# Processed: ./UF/NHB190512023008.uf
# Processed: ./UF/NHB190511030240.uf
# Processed: ./UF/NHB190513002240.uf
# Processed: ./UF/NHB190511230008.uf
# Processed: ./UF/NHB190513034239.uf
# Processed: ./UF/NHB190513002007.uf
# Processed: ./UF/NHB190512002007.uf
# Processed: ./UF/NHB190511030007.uf
# Processed: ./UF/NHB190513010239.uf
# Processed: ./UF/NHB190511022239.uf
# Processed: ./UF/NHB190511051240.uf
# Processed: ./UF/NHB190511014007.uf
# Processed: ./UF/NHB190513063007.uf
# Processed: ./UF/NHB190511235240.uf
# Processed: ./UF/NHB190511070008.uf
# Processed: ./UF/NHB190511035008.uf
# Processed: ./UF/NHB190512231239.uf
# Processed: ./UF/NHB190511134240.uf
# Processed: ./UF/NHB190511134007.uf
# Processed: ./UF/NHB190513095239.uf
# Processed: ./UF/NHB190512143007.uf
# Processed: ./UF/NHB190511121239.uf
# Processed: ./UF/NHB190513080007.uf
# Processed: ./UF/NHB190511084239.uf
# Processed: ./UF/NHB190513080240.uf
# Processed: ./UF/NHB190511001239.uf
# Processed: ./UF/NHB190511072240.uf
# Processed: ./UF/NHB190512141008.uf
# Processed: ./UF/NHB190513104008.uf
# Processed: ./UF/NHB190513033239.uf
# Processed: ./UF/NHB190513040240.uf
# Processed: ./UF/NHB190512005240.uf
# Processed: ./UF/NHB190511072007.uf
# Processed: ./UF/NHB190513021240.uf
# Processed: ./UF/NHB190512021240.uf
# Processed: ./UF/NHB190511060239.uf
# Processed: ./UF/NHB190513085008.uf
# Processed: ./UF/NHB190512021007.uf
# Processed: ./UF/NHB190513101240.uf
# Processed: ./UF/NHB190512000008.uf
# Processed: ./UF/NHB190513044006.uf
# Processed: ./UF/NHB190513001006.uf
# Processed: ./UF/NHB190511032008.uf
# Processed: ./UF/NHB190513092239.uf
# Processed: ./UF/NHB190511133007.uf
# Processed: ./UF/NHB190510232007.uf
# Processed: ./UF/NHB190511232007.uf
# Processed: ./UF/NHB190511142239.uf
# Processed: ./UF/NHB190511075008.uf
# Processed: ./UF/NHB190513003006.uf
# Processed: ./UF/NHB190511094007.uf
# Processed: ./UF/NHB190513103240.uf
# Processed: ./UF/NHB190511094240.uf
# Processed: ./UF/NHB190513103007.uf
# Processed: ./UF/NHB190511131007.uf
# Processed: ./UF/NHB190513090239.uf
# Processed: ./UF/NHB190511110008.uf
# Processed: ./UF/NHB190511011240.uf
# Processed: ./UF/NHB190513023240.uf
# Processed: ./UF/NHB190512023240.uf
# Processed: ./UF/NHB190513042240.uf
# Processed: ./UF/NHB190512031239.uf
# Processed: ./UF/NHB190513031239.uf
# Processed: ./UF/NHB190511235008.uf
# Processed: ./UF/NHB190513074239.uf
# Processed: ./UF/NHB190511070240.uf
# Processed: ./UF/NHB190510234006.uf
# Processed: ./UF/NHB190511003239.uf
# Processed: ./UF/NHB190511091008.uf
# Processed: ./UF/NHB190513042007.uf
# Processed: ./UF/NHB190513111239.uf
# Processed: ./UF/NHB190512154239.uf
# Processed: ./UF/NHB190511115240.uf
# Processed: ./UF/NHB190513082007.uf
# Processed: ./UF/NHB190511123239.uf
# Processed: ./UF/NHB190511051008.uf
# Processed: ./UF/NHB190511115007.uf
# Processed: ./UF/NHB190511150007.uf
# Processed: ./UF/NHB190511074007.uf
# Processed: ./UF/NHB190511031007.uf
# Processed: ./UF/NHB190511074240.uf
# Processed: ./UF/NHB190511031240.uf
# Processed: ./UF/NHB190513070239.uf
# Processed: ./UF/NHB190511082239.uf
# Processed: ./UF/NHB190513123007.uf
# Processed: ./UF/NHB190511111007.uf
# Processed: ./UF/NHB190511111240.uf
# Processed: ./UF/NHB190511010008.uf
# Processed: ./UF/NHB190513123240.uf
# Processed: ./UF/NHB190513115239.uf
# Processed: ./UF/NHB190513094239.uf
# Processed: ./UF/NHB190512142007.uf
# Processed: ./UF/NHB190511234007.uf
# Processed: ./UF/NHB190512142240.uf
# Processed: ./UF/NHB190510234240.uf
# Processed: ./UF/NHB190511090007.uf
# Processed: ./UF/NHB190511103239.uf
# Processed: ./UF/NHB190511071008.uf
# Processed: ./UF/NHB190511015007.uf
# Processed: ./UF/NHB190513011239.uf
# Processed: ./UF/NHB190513054239.uf
# Processed: ./UF/NHB190511023239.uf
# Processed: ./UF/NHB190511114008.uf
# Processed: ./UF/NHB190512025007.uf
# Processed: ./UF/NHB190513081008.uf
# Processed: ./UF/NHB190511052007.uf
# Processed: ./UF/NHB190511064239.uf
# Processed: ./UF/NHB190512013239.uf
# Processed: ./UF/NHB190513013239.uf
# Processed: ./UF/NHB190513105007.uf
# Processed: ./UF/NHB190513040006.uf
# Processed: ./UF/NHB190512005006.uf
# Processed: ./UF/NHB190511144239.uf
# Processed: ./UF/NHB190511073008.uf
# Processed: ./UF/NHB190511092007.uf
# Processed: ./UF/NHB190513105240.uf
# Processed: ./UF/NHB190512004008.uf
# Processed: ./UF/NHB190513120009.uf
# Processed: ./UF/NHB190513065008.uf
# Processed: ./UF/NHB190512152239.uf
# Processed: ./UF/NHB190512020008.uf
# Processed: ./UF/NHB190511125239.uf
# Processed: ./UF/NHB190513084007.uf
# Processed: ./UF/NHB190511033007.uf
# Processed: ./UF/NHB190511232241.uf
# Processed: ./UF/NHB190513100008.uf
# Processed: ./UF/NHB190511233008.uf
# Processed: ./UF/NHB190513072239.uf
# Processed: ./UF/NHB190513001240.uf
# Processed: ./UF/NHB190512001240.uf
# PNG files exported to: ./radar_png
